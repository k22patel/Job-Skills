# %%
#Install firefox
# !apt-get update
# !apt install firefox

#Install selenium
# !pip install selenium

#Updating and installing firefox libraries
# !apt-get update && apt-get install -y wget bzip2 libxtst6 libgtk-3-0 libx11-xcb-dev libdbus-glib-1-2 libxt6 libpci-dev && rm -rf /var/lib/apt/lists/*

#Installing Geck Driver
# !wget https://github.com/mozilla/geckodriver/releases/download/v0.24.0/geckodriver-v0.24.0-linux64.tar.gz
# !tar -xvzf geckodriver*
# !chmod +x geckodriver
# !export PATH=$PATH:/path-to-extracted-file/.

#Instal beautifulsoup
# !pip install beautifulsoup4
# Out:
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: selenium in c:\users\patel\anaconda3\lib\site-packages (4.15.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\patel\anaconda3\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in c:\users\patel\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\patel\anaconda3\lib\site-packages (from selenium) (2023.7.22)
# Requirement already satisfied: trio~=0.17 in c:\users\patel\anaconda3\lib\site-packages (from selenium) (0.23.1)
# Requirement already satisfied: sortedcontainers in c:\users\patel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\patel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\patel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.3)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\patel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: attrs>=20.1.0 in c:\users\patel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\patel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: cffi>=1.14 in c:\users\patel\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\patel\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\patel\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\patel\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\patel\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# tar: Error opening archive: Failed to open 'geckodriver*'
# 'chmod' is not recognized as an internal or external command,
# operable program or batch file.
# 'export' is not recognized as an internal or external command,
# operable program or batch file.
# Requirement already satisfied: beautifulsoup4 in c:\users\patel\anaconda3\lib\site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\patel\anaconda3\lib\site-packages (from beautifulsoup4) (2.3.1)

# %%
import selenium.webdriver as webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options as FirefoxOptions

import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By

import random
import time

# %%
## Enter a job position
position = "data+scientist"
## Enter a location (City, State or Zip or remote)
locations = "USA"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])
print(url)
# Out:
# https://www.indeed.com/jobs?q=data+scientist&l=USA

# %%
driver_path = '/content/geckodriver'
firefox_driver_path = '/content/geckodriver'
user_agent = 'Mozilla'
firefox_options = FirefoxOptions()
firefox_options.add_argument('--headless')
driver = webdriver.Firefox(options=firefox_options)

# %%
## Number of postings to scrape
postings = 1000

jn=0
for i in range(0, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(3)

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')
    #print(jobs)

    for job in jobs:
        #print(job)
        result_html = job.get_attribute('innerHTML')
        #print(result_html)
        soup = BeautifulSoup(result_html, 'html.parser')
        #print(soup , '\n')

        jn += 1

        liens = job.find_elements(By.TAG_NAME, "a")
        #print(liens)
        links = liens[0].get_attribute("href")
        #print(links)

        title = soup.select('.jobTitle')[0].get_text().strip()
        print(title)

        #company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip()
        #print(company)
        try:
            company = soup.find_all(attrs={'data-testid': 'company-name'})[0].get_text().strip()
            #print(company)
        except:
            company = 'Nan'
        print(company)
        #location = soup.select('.companyLocation')[0].get_text().strip() #origional
        #location = soup.select('.company_location')[0].get_text().strip()
        location = soup.find_all(attrs={'data-testid': 'text-location'})[0].get_text().strip()
        print(location)
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''

        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))
# Out:
# Principal Data Science
# Discover Financial Services
# Riverwoods, IL 60015
# Job number    1 added - Principal Data Science
# Data Scientist
# SOSi
# Redstone Arsenal, AL
# Job number    2 added - Data Scientist
# Scientist/Principal Scientist, Drug Product Development Statistician
# Bristol Myers Squibb
# Summit, NJ 07901
# Job number    3 added - Scientist/Principal Scientist, Drug Product Development Statistician
# Data Scientist
# Kaizen Analytix
# Remote
# Job number    4 added - Data Scientist
# Data Scientist
# NYC Health + Hospitals
# Remote in New York, NY
# Job number    5 added - Data Scientist
# Data Scientist
# ABN Tech Corp
# Woodland Hills, CA
# Job number    6 added - Data Scientist
# Data Scientist
# Hang
# Remote in California
# Job number    7 added - Data Scientist
# Data Scientist
# Boston Services
# Auburn Hills, MI 48326
# Job number    8 added - Data Scientist
# Data Scientist
# Camping World
# Hybrid remote in Lincolnshire, IL 60069
# Job number    9 added - Data Scientist
# Data Scientist
# US Heathcare Product Company
# Remote
# Job number   10 added - Data Scientist
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number   11 added - Senior Software Engineer w/AI Focus
# Data Scientist
# REMEDI8
# Remote in Madison, WI
# Job number   12 added - Data Scientist
# Data Scientist
# Midea
# Parsippany, NJ 07054
# Job number   13 added - Data Scientist
# Jr. Data Scientist
# ClimateAI
# Remote
# Job number   14 added - Jr. Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number   15 added - Senior Open-Source Data Scientist Consultant
# Python Data Scientist
# Synovize
# Remote
# Job number   16 added - Python Data Scientist
# Sr. Staff Data Scientist, Marketplace
# Veho
# Remote
# Job number   17 added - Sr. Staff Data Scientist, Marketplace
# Data Scientist
# Thalo Labs
# Brooklyn, NY
# Job number   18 added - Data Scientist
# Data Scientist
# Cloudflare
# Remote in Austin, TX
# Job number   19 added - Data Scientist
# Data Scientist
# Wiliot
# Remote
# Job number   20 added - Data Scientist
# Data Scientist
# CORMAC
# Remote
# Job number   21 added - Data Scientist
# Data Scientist- Innovation
# Domino's Corporate
# Ann Arbor, MI 48105
# Job number   22 added - Data Scientist- Innovation
# Data Scientist
# Texas Children's Hospital
# Houston, TX 77001
# Job number   23 added - Data Scientist
# Data Scientist
# Caliber Financial Services
# Overland Park, KS 66210
# Job number   24 added - Data Scientist
# Data Scientist
# PerfectRec
# Remote in Washington, DC
# Job number   25 added - Data Scientist
# Data Scientist
# UCLA Health
# Los Angeles, CA 90095
# Job number   26 added - Data Scientist
# Data Scientist
# National Committee for Quality Assurance
# Washington, DC 20005 (Downtown area)
# Job number   27 added - Data Scientist
# Data Scientist
# Trinity Industries
# Dallas, TX 75254 (Far North area)
# Job number   28 added - Data Scientist
# Data Scientist
# Vedainfo
# Remote
# Job number   29 added - Data Scientist
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number   30 added - Senior Software Engineer w/AI Focus
# Data Scientist
# Digitas
# New York, NY 10014 (SoHo area)
# Job number   31 added - Data Scientist
# Data Scientist
# The Chefs' Warehouse
# Remote
# Job number   32 added - Data Scientist
# Arity-Data Scientist- Remote
# Allstate
# Remote in Chicago, IL
# Job number   33 added - Arity-Data Scientist- Remote
# Data Scientist
# Fooda
# Chicago, IL
# Job number   34 added - Data Scientist
# LTD Data Scientist - Returnship
# INTEL
# Remote
# Job number   35 added - LTD Data Scientist - Returnship
# Data Scientist
# Object Technology Solutions Inc
# Coppell, TX
# Job number   36 added - Data Scientist
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number   37 added - Senior Software Engineer w/AI Focus
# Data Scientist
# V15P1TALONNN
# Bell Gardens, CA 90201
# Job number   38 added - Data Scientist
# Healthcare Data Scientist
# Hennepin Healthcare
# Hybrid remote in Minneapolis, MN 55415
# Job number   39 added - Healthcare Data Scientist
# Data Scientist, Core AI
# Indeed
# Remote
# Job number   40 added - Data Scientist, Core AI
# Data Scientist
# SGS
# Rutherford, NJ 07070
# Job number   41 added - Data Scientist
# Data Scientist
# MantraSys
# Atlanta, GA
# Job number   42 added - Data Scientist
# Data Scientist III
# KiwiCo
# Hybrid remote in Mountain View, CA
# Job number   43 added - Data Scientist III
# Data Scientist
# Lendistry
# Tustin, CA
# Job number   44 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number   45 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# QinetiQ US
# Fort Liberty, NC
# Job number   46 added - Data Scientist
# Data Scientist I
# Reliance Steel & Aluminum Co.
# Cypress, CA 90630
# Job number   47 added - Data Scientist I
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number   48 added - Senior Software Engineer w/AI Focus
# Data Scientist
# Accelerate Diagnostics Inc
# Tucson, AZ 85714 (Fairgrounds area)
# Job number   49 added - Data Scientist
# Data Scientist
# COEADAPT INC.
# Remote
# Job number   50 added - Data Scientist
# Rotational Development Program: Data Scientist
# AGCO
# Duluth, GA 30096
# Job number   51 added - Rotational Development Program: Data Scientist
# Data Scientist
# Veear Projects Inc.
# Remote
# Job number   52 added - Data Scientist
# Data Scientist
# Merge API
# San Francisco, CA
# Job number   53 added - Data Scientist
# Data Scientist
# Pacaso
# Remote
# Job number   54 added - Data Scientist
# Data Scientist AdTech
# I20 Technologies
# Remote in Santa Clara, CA
# Job number   55 added - Data Scientist AdTech
# Data Scientist
# Yext
# New York, NY 10010 (NoMad area)
# Job number   56 added - Data Scientist
# Data Scientist
# Business Intelligence & Informatics Consulting...
# Hybrid remote in Tallahassee, FL 32303
# Job number   57 added - Data Scientist
# Jr. Data Scientist
# Florida Atlantic University
# Boca Raton, FL 33431
# Job number   58 added - Jr. Data Scientist
# Healthcare Data Scientist
# GORDON Limited Liability Company
# Remote
# Job number   59 added - Healthcare Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number   60 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# CAPITAL Services
# Sioux Falls, SD 57110
# Job number   61 added - Data Scientist
# Data Scientist
# The Voleon Group
# Hybrid remote in Berkeley, CA
# Job number   62 added - Data Scientist
# Data Scientist
# ShyftLabs
# Remote in Denver, CO
# Job number   63 added - Data Scientist
# Data Scientist
# VidMob
# Remote
# Job number   64 added - Data Scientist
# Data Scientist
# GenTech Associates
# Indianapolis, IN
# Job number   65 added - Data Scientist
# Data Scientist
# AG Grace Inc
# Fort Eisenhower, GA 30905
# Job number   66 added - Data Scientist
# Commercial Data Scientist III
# Signature Flight Support
# Orlando, FL
# Job number   67 added - Commercial Data Scientist III
# Staff Data Scientist
# Imagine Pediatrics
# Remote in Nashville, TN
# Job number   68 added - Staff Data Scientist
# Data Scientist | ML
# Machinify
# Remote in California
# Job number   69 added - Data Scientist | ML
# Data Scientist, Business Analytics
# Thumbtack
# Remote in San Francisco, CA
# Job number   70 added - Data Scientist, Business Analytics
# Senior Data Scientist
# Pluto TV
# Remote in New York, NY 10036
# Job number   71 added - Senior Data Scientist
# Data Scientist
# Apple
# Austin, TX
# Job number   72 added - Data Scientist
# Data Scientist (L5) - Infrastructure Experimentation
# Netflix
# Remote
# Job number   73 added - Data Scientist (L5) - Infrastructure Experimentation
# Data Scientist
# Buchanan And Edwards Group
# McLean, VA 22043
# Job number   74 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number   75 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# TechTrueUP
# Thousand Oaks, CA
# Job number   76 added - Data Scientist
# Data Scientist
# AppsIntegration.Inc
# Remote
# Job number   77 added - Data Scientist
# Data Scientist
# Praxis Precision Medicines
# Remote in Charlestown, MA 02129
# Job number   78 added - Data Scientist
# Data Scientist
# Tekrek Solutions Inc
# Remote
# Job number   79 added - Data Scientist
# Data Entry/Editor
# TSOLife
# Remote
# Job number   80 added - Data Entry/Editor
# Data Scientist
# DATACOLOR INC
# Lawrenceville, NJ 08648
# Job number   81 added - Data Scientist
# Data Scientist
# Edgesource
# Hybrid remote in Vienna, VA 22182
# Job number   82 added - Data Scientist
# Data Scientist
# Idea Evolver
# Remote
# Job number   83 added - Data Scientist
# Associate Data Scientist / Data Scientist
# Day Zero Diagnostics
# Boston, MA
# Job number   84 added - Associate Data Scientist / Data Scientist
# Data Scientist
# HCSC
# Hybrid remote in Chicago, IL
# Job number   85 added - Data Scientist
# Data Scientist
# Zartico, Inc.
# Remote
# Job number   86 added - Data Scientist
# Data Scientist
# Combined Insurance
# Jersey City, NJ
# Job number   87 added - Data Scientist
# Data Scientist
# ASET Partners
# Quantico, VA
# Job number   88 added - Data Scientist
# CO-OP, Data Scientist
# Saint-Gobain Research North America
# Northborough, MA 01532
# Job number   89 added - CO-OP, Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number   90 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Paycom
# Oklahoma City, OK 73116
# Job number   91 added - Data Scientist
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number   92 added - Senior Software Engineer w/AI Focus
# Data Scientist
# Brik Partners
# Remote
# Job number   93 added - Data Scientist
# Data Scientist
# Tellus solutions
# San Bruno, CA
# Job number   94 added - Data Scientist
# Data Scientist
# Koddi
# Remote
# Job number   95 added - Data Scientist
# Data Scientist
# Bilin Technology
# Boston, MA
# Job number   96 added - Data Scientist
# MACA Data Scientist
# Intuitive
# Peachtree Corners, GA
# Job number   97 added - MACA Data Scientist
# Senior Data Scientist
# Georgia Transmission Corporation
# Tucker, GA 30084
# Job number   98 added - Senior Data Scientist
# Data Scientist, Analytics
# Next Insurance
# Palo Alto, CA
# Job number   99 added - Data Scientist, Analytics
# Data Scientist
# Infinia ML
# Hybrid remote in Durham, NC 27703
# Job number  100 added - Data Scientist
# Data Scientist
# Extreme Data Technologies
# Hybrid remote in East Orange, NJ 07018
# Job number  101 added - Data Scientist
# Data Scientist
# Grid
# San Francisco, CA 94123 (Marina area)
# Job number  102 added - Data Scientist
# Data Scientist Jr.
# Optimal Solutions Group
# College Park, MD 20740
# Job number  103 added - Data Scientist Jr.
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  104 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Excelsior University
# Albany, NY 12203 (Campus Area-University District area)
# Job number  105 added - Data Scientist
# Data Scientist
# Signature Science, LLC
# Austin, TX
# Job number  106 added - Data Scientist
# Data Analyst
# Argot Partners
# Houston, TX
# Job number  107 added - Data Analyst
# Data Scientist
# Truth Initiative
# Hybrid remote in Washington, DC 20001
# Job number  108 added - Data Scientist
# Data Scientist
# ASK Consulting
# Oceanside, CA
# Job number  109 added - Data Scientist
# Data Scientist
# SourceMantra
# Reston, VA
# Job number  110 added - Data Scientist
# Data Scientist
# DMI
# Hybrid remote in Auburn Hills, MI 48326
# Job number  111 added - Data Scientist
# Data Scientist, Analytics
# Parafin
# San Francisco, CA
# Job number  112 added - Data Scientist, Analytics
# Associate Data Scientist
# UMUC Ventures
# Hyattsville, MD 20783
# Job number  113 added - Associate Data Scientist
# Senior Data Scientist
# Strike Social
# Remote
# Job number  114 added - Senior Data Scientist
# Data Scientist – BCG X
# Boston Consulting Group
# Washington, DC
# Job number  115 added - Data Scientist – BCG X
# Data Scientist
# US Central Intelligence Agency
# Washington, DC
# Job number  116 added - Data Scientist
# Senior Data Scientist
# Brigit
# Remote in California
# Job number  117 added - Senior Data Scientist
# Data Scientist II
# Fairfax County Government
# Fairfax, VA 22035
# Job number  118 added - Data Scientist II
# Data Scientist
# Axuall
# Remote
# Job number  119 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  120 added - Senior Open-Source Data Scientist Consultant
# Staff Applied Scientist, Marketplace
# ThredUp Inc.
# Hybrid remote in Oakland, CA 94607
# Job number  121 added - Staff Applied Scientist, Marketplace
# Data Scientist
# Federal Bureau of Investigation
# Washington, DC 20535 (Penn Quarter area)
# Job number  122 added - Data Scientist
# Data Scientist
# NutaNXT Technologies
# Santa Clara, CA
# Job number  123 added - Data Scientist
# Data Scientist
# Steneral Consulting
# Hybrid remote in Indianapolis, IN
# Job number  124 added - Data Scientist
# Data Scientist
# Zimmerman Advertising
# Fort Lauderdale, FL
# Job number  125 added - Data Scientist
# Data Scientist (-)
# DCI Solutions
# Bethesda, MD
# Job number  126 added - Data Scientist (-)
# Data Scientist
# Sbase Technology Inc.
# Remote
# Job number  127 added - Data Scientist
# PDC JUNIOR DATA SCIENTIST – ID# 223758
# Research Corporation of the University of Hawaii
# Kīhei, HI
# Job number  128 added - PDC JUNIOR DATA SCIENTIST – ID# 223758
# Sr Data Scientist
# Summit Therapeutics Sub, Inc.
# Menlo Park, CA 94025
# Job number  129 added - Sr Data Scientist
# Jr. Data Scientist
# Innovative Defense Technologies (IDT)
# Mount Laurel, NJ 08054
# Job number  130 added - Jr. Data Scientist
# Data Scientist
# iOLAP
# Frisco, TX
# Job number  131 added - Data Scientist
# Data Scientist
# US Department of Veterans Affairs
# Washington, DC 20420 (Downtown area)
# Job number  132 added - Data Scientist
# Data Scientist
# COGNIZE TECH SOLUTIONS
# Remote
# Job number  133 added - Data Scientist
# Data Scientist
# The University of Pittsburgh
# Pittsburgh, PA
# Job number  134 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  135 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Atmos Energy
# New Orleans, LA
# Job number  136 added - Data Scientist
# Data Scientist
# Datasync Techonlogies Inc
# Herndon, VA 20170
# Job number  137 added - Data Scientist
# Data Scientist
# Fulcrum Analytics
# Remote
# Job number  138 added - Data Scientist
# Data Scientist
# Vibronyx
# Remote
# Job number  139 added - Data Scientist
# Data Scientist, Membership Programs
# Petco
# San Diego, CA 92127
# Job number  140 added - Data Scientist, Membership Programs
# Data Scientist
# Vail Resorts
# Remote
# Job number  141 added - Data Scientist
# Data Scientist
# Victory
# Remote
# Job number  142 added - Data Scientist
# Data Scientist
# NORC at the University of Chicago
# Chicago, IL
# Job number  143 added - Data Scientist
# Machine Learning Data Scientist
# Itemize Corp.
# Remote
# Job number  144 added - Machine Learning Data Scientist
# Data Scientist
# Micron
# Manassas, VA
# Job number  145 added - Data Scientist
# Data Scientist
# Florida Atlantic University
# Boca Raton, FL 33431
# Job number  146 added - Data Scientist
# Business Unit Data Scientist
# Regions
# Atlanta, TX 75551
# Job number  147 added - Business Unit Data Scientist
# Data Scientist
# BICP
# San Francisco, CA
# Job number  148 added - Data Scientist
# Data Scientist
# Attain
# Hybrid remote in Redwood City, CA
# Job number  149 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  150 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# The Center For Organizational Excellence, Inc
# Rockville, MD 20850
# Job number  151 added - Data Scientist
# Data Scientist - Indianapolis Health
# Milliman
# Hybrid remote in Indianapolis, IN 46204
# Job number  152 added - Data Scientist - Indianapolis Health
# Senior Data Scientist
# AS&E
# Billerica, MA 01821
# Job number  153 added - Senior Data Scientist
# Data Scientist
# Mayvue
# Remote in Pittsburgh, PA 15212
# Job number  154 added - Data Scientist
# Data Scientist (entry-level)
# JRC Integrated Systems, LLC
# Crane, IN 47522
# Job number  155 added - Data Scientist (entry-level)
# Data Scientist
# QIAGEN
# Ann Arbor, MI
# Job number  156 added - Data Scientist
# Data Scientist
# Perry Homes, LLC
# Houston, TX 77027 (River Oaks area)
# Job number  157 added - Data Scientist
# Data Scientist, Creators
# Notion
# New York, NY
# Job number  158 added - Data Scientist, Creators
# Data Scientist ll
# RAC Brands
# Hybrid remote in Draper, UT 84020
# Job number  159 added - Data Scientist ll
# Data Scientist
# Integra Connect
# Remote
# Job number  160 added - Data Scientist
# Data Scientist
# ADP
# Alpharetta, GA
# Job number  161 added - Data Scientist
# Geospatial Data Scientist
# AVA Counsulting
# Mountain View, CA
# Job number  162 added - Geospatial Data Scientist
# Data Scientist
# Regal Rexnord
# Milwaukee, WI
# Job number  163 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  164 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Publicis Media
# New York, NY 10014 (SoHo area)
# Job number  165 added - Data Scientist
# Data Scientist
# Kickstarter.com
# Remote
# Job number  166 added - Data Scientist
# Data Scientist (Multiple areas of expertise) -E
# Kingfisher Systems, Inc.
# McLean, VA 22101
# Job number  167 added - Data Scientist (Multiple areas of expertise) -E
# Data Scientist (Commercial Strategy)
# Disney
# Hybrid remote in Lake Buena Vista, FL
# Job number  168 added - Data Scientist (Commercial Strategy)
# Senior Data Scientist
# Deepcell
# Menlo Park, CA 94025 (Lorelei Manor area)
# Job number  169 added - Senior Data Scientist
# Data Scientist
# AmeriTEK Global
# Piscataway, NJ 08854
# Job number  170 added - Data Scientist
# Data Scientist
# BPGbio
# Framingham, MA 01701
# Job number  171 added - Data Scientist
# Machine Learning Developer
# D. E. Shaw & Co., L.P.
# New York, NY
# Job number  172 added - Machine Learning Developer
# Senior Data Scientist - 2199648
# Optum
# Eden Prairie, MN 55346
# Job number  173 added - Senior Data Scientist - 2199648
# IN - IDOH Data Scientist
# NextRow Digital
# Indianapolis, IN
# Job number  174 added - IN - IDOH Data Scientist
# Data Scientist
# ROSEN Group
# Columbus, OH 43230
# Job number  175 added - Data Scientist
# Data Scientist
# Techsara solutions Inc
# Hybrid remote in Tampa, FL 33602
# Job number  176 added - Data Scientist
# Data Scientist - Davis Center
# Minneapolis Public Schools
# Minneapolis, MN 55411 (Jordan area)
# Job number  177 added - Data Scientist - Davis Center
# Data Analyst/Senior Data Analyst
# Institute for Women's Policy Research
# Washington, DC 20036 (Downtown area)
# Job number  178 added - Data Analyst/Senior Data Analyst
# Data Scientist
# Boston Metal
# Woburn, MA 01801
# Job number  179 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  180 added - Senior Open-Source Data Scientist Consultant
# Data Scientist (Provo, UT)
# ZONTAL Inc
# Provo, UT
# Job number  181 added - Data Scientist (Provo, UT)
# Data Scientist
# High Point Aerotechnologies
# Hybrid remote in Fairfax, VA
# Job number  182 added - Data Scientist
# Staff Data Scientist
# Devoted Health
# Remote
# Job number  183 added - Staff Data Scientist
# Senior Data Scientist - Applied ML
# AstraZeneca
# Waltham, MA 02451
# Job number  184 added - Senior Data Scientist - Applied ML
# Data Scientist
# Parkview Health
# Fort Wayne, IN 46808
# Job number  185 added - Data Scientist
# Data Scientist
# Lawrence Berkeley National Laboratory
# San Francisco Bay Area, CA
# Job number  186 added - Data Scientist
# Data Scientist, All Levels
# Independent Software
# Fort Meade, MD 20755
# Job number  187 added - Data Scientist, All Levels
# Data Scientist
# Nan
# Pasadena, CA
# Job number  188 added - Data Scientist
# Data Scientist
# Northwestern University
# Evanston, IL
# Job number  189 added - Data Scientist
# Data Scientist - Junior
# Titan Technologies LLC
# Dothan, AL 36305
# Job number  190 added - Data Scientist - Junior
# Jr. Data Scientist
# Core One
# Tampa, FL
# Job number  191 added - Jr. Data Scientist
# Senior Data Scientist
# Cisco Meraki
# Remote in San Francisco, CA
# Job number  192 added - Senior Data Scientist
# Data Scientist
# V2Soft
# Mountain View, CA 94041 (Old Mountain View area)
# Job number  193 added - Data Scientist
# Data Scientist
# Mineral
# Remote in Mountain View, CA
# Job number  194 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  195 added - Senior Open-Source Data Scientist Consultant
# Data Scientist - Power Systems
# GE Digital
# Remote in California
# Job number  196 added - Data Scientist - Power Systems
# Data Scientist / Senior Data Scientist
# Diagnoseearly Holdings, Inc.
# Menlo Park, CA
# Job number  197 added - Data Scientist / Senior Data Scientist
# Data Scientist - Public Sector
# Clarifai
# Remote
# Job number  198 added - Data Scientist - Public Sector
# DATA SCIENTIST
# Big Bright International
# Chicago, IL
# Job number  199 added - DATA SCIENTIST
# Data Analyst – Data Entry
# Juristat
# Remote
# Job number  200 added - Data Analyst – Data Entry
# Data Scientist
# Plymouth Rock Assurance
# Boston, MA 02111 (Leather District area)
# Job number  201 added - Data Scientist
# AI Engineer/Data Scientist
# TMPI
# Minneapolis, MN 55411 (Near North area)
# Job number  202 added - AI Engineer/Data Scientist
# Sr Data Scientist
# CEDENT
# Atlanta, GA
# Job number  203 added - Sr Data Scientist
# Data Scientist
# Fabrx Space
# Remote
# Job number  204 added - Data Scientist
# Data Scientist
# ATI
# Monroe, NC 28111
# Job number  205 added - Data Scientist
# Data Scientist - All Levels
# Interclypse Inc
# San Antonio, TX
# Job number  206 added - Data Scientist - All Levels
# Data Scientist
# Wipro Limited
# Tampa, FL
# Job number  207 added - Data Scientist
# Principal Data Scientist
# CEDENT
# Nashville, TN
# Job number  208 added - Principal Data Scientist
# Data Scientist
# Frankenmuth Insurance Company
# Remote in Michigan
# Job number  209 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  210 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# US Department of Energy - Agency Wide
# Wallops Island, VA
# Job number  211 added - Data Scientist
# Data Scientist
# The AES Corporation
# Indianapolis, IN
# Job number  212 added - Data Scientist
# Data Scientist
# Lirio
# Remote in Knoxville, TN
# Job number  213 added - Data Scientist
# Data Scientist
# Nexlogica
# Remote
# Job number  214 added - Data Scientist
# Data Scientist
# WindESCo
# Remote
# Job number  215 added - Data Scientist
# Data Scientist
# Assetario
# Remote
# Job number  216 added - Data Scientist
# Data Scientist - Primary Care Organization
# CenterWell
# Remote
# Job number  217 added - Data Scientist - Primary Care Organization
# Data Scientist, Sr. (Full time remote)
# Lockheed Martin Corporation
# Remote in Moorestown, NJ
# Job number  218 added - Data Scientist, Sr. (Full time remote)
# Data Scientist
# Diverge Health
# Remote in Chicago, IL
# Job number  219 added - Data Scientist
# Data Scientist II - Workforce Surveys and Ana
# GovStrive LLC
# Remote in Atlanta, GA
# Job number  220 added - Data Scientist II - Workforce Surveys and Ana
# Data Scientist I
# University of Southern Mississippi
# Gulfport, MS 39501
# Job number  221 added - Data Scientist I
# Data Scientist
# Novisync
# Remote
# Job number  222 added - Data Scientist
# Data Scientist/Analytics
# Baystate Health
# Springfield, MA
# Job number  223 added - Data Scientist/Analytics
# Data Scientist
# Tepa
# Remote in San Diego, CA 92101
# Job number  224 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  225 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Tepa
# Remote in San Diego, CA 92101
# Job number  226 added - Data Scientist
# Data Scientist
# Context Labs
# Cambridge, MA 02142 (East Cambridge area)
# Job number  227 added - Data Scientist
# Data Scientist
# VivusTech
# Chantilly, VA
# Job number  228 added - Data Scientist
# Data Scientist
# Indiana University Health
# Remote in Indianapolis, IN 46202
# Job number  229 added - Data Scientist
# Staff Data Scientist
# Turing
# Remote
# Job number  230 added - Staff Data Scientist
# Expert Data Scientist
# ANSER
# Washington, DC 20032 (Anacostia area)
# Job number  231 added - Expert Data Scientist
# Data Scientist
# Finrise
# Burlingame, CA
# Job number  232 added - Data Scientist
# Data Scientist(Marketing)
# ASA
# Remote
# Job number  233 added - Data Scientist(Marketing)
# Senior Data Scientist- Optimization
# Corteva
# Indianapolis, IN 46268
# Job number  234 added - Senior Data Scientist- Optimization
# Data Scientist
# Old Dominion Freight Line
# Thomasville, NC 27360
# Job number  235 added - Data Scientist
# Data Scientist
# DT Professional Services
# Remote
# Job number  236 added - Data Scientist
# Data Scientist I (Bloom Lab)
# Fred Hutchinson Cancer Center
# Seattle, WA
# Job number  237 added - Data Scientist I (Bloom Lab)
# Data Scientist
# Knowesis
# Remote in Alexandria, VA
# Job number  238 added - Data Scientist
# Data Scientist
# Triunity Software
# Los Angeles, CA 90012
# Job number  239 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  240 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Ai Vantage
# Hybrid remote in Vienna, VA 22182
# Job number  241 added - Data Scientist
# Data Scientist Winter/Spring Co-Op
# Skyworks
# Newbury Park, CA
# Job number  242 added - Data Scientist Winter/Spring Co-Op
# Sr. Data Scientist - Machine Learning
# Shoptrue, Inc.
# Remote
# Job number  243 added - Sr. Data Scientist - Machine Learning
# Senior Data Scientist
# Microsoft
# Redmond, WA 98052 (Overlake area)
# Job number  244 added - Senior Data Scientist
# Data Scientist
# Ovative Group, LLC
# Minneapolis, MN 55401 (North Loop area)
# Job number  245 added - Data Scientist
# Research Scientist I, Metabolomics Data
# Ellison Institute of Technology
# Los Angeles, CA
# Job number  246 added - Research Scientist I, Metabolomics Data
# Evaluation & Data Scientist
# University of Oklahoma
# Norman, OK
# Job number  247 added - Evaluation & Data Scientist
# Data Scientist
# TriNet
# Remote
# Job number  248 added - Data Scientist
# Data Scientist
# Zen Strategics LLC
# Remote
# Job number  249 added - Data Scientist
# 2024 Co-Op, Artificial Intelligence
# Moderna
# Cambridge, MA 02139 (The Port area)
# Job number  250 added - 2024 Co-Op, Artificial Intelligence
# Metrics Data Scientist (Maps Evaluation)
# Apple
# Cupertino, CA
# Job number  251 added - Metrics Data Scientist (Maps Evaluation)
# Data Scientist, Product Analytics
# Gusto, Inc.
# New York, NY
# Job number  252 added - Data Scientist, Product Analytics
# Data Scientist
# Elder Research Inc
# Springfield, VA 22150
# Job number  253 added - Data Scientist
# Data Scientist
# Sphinx LLC
# Quantico, VA 22134
# Job number  254 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  255 added - Senior Open-Source Data Scientist Consultant
# Principal Data Scientist
# Teamware Solutions (quantum leap consulting).
# Remote
# Job number  256 added - Principal Data Scientist
# Senior Data Scientist
# Cambridge Mobile Telematics
# Cambridge, MA
# Job number  257 added - Senior Data Scientist
# Senior Data Scientist
# Cogitativo
# Berkeley, CA
# Job number  258 added - Senior Data Scientist
# Senior Data Scientist
# OnSolve LLC
# Alpharetta, GA 30009
# Job number  259 added - Senior Data Scientist
# Data Scientist Trainee
# Axle Informatics
# Rockville, MD 20852
# Job number  260 added - Data Scientist Trainee
# Data Scientist - Multiple Levels
# DeNOVO Solutions
# Aurora, CO
# Job number  261 added - Data Scientist - Multiple Levels
# DATA SCIENTIST
# William Blair & Company
# Chicago, IL 60606 (West Loop Gate area)
# Job number  262 added - DATA SCIENTIST
# Staff Data Scientist
# Classy
# Remote in San Diego, CA 92126
# Job number  263 added - Staff Data Scientist
# Data Scientist
# R&K Cyber Solutions
# Hybrid remote in Knoxville, TN
# Job number  264 added - Data Scientist
# Data scientist
# Ntropy Network
# Remote in New York, NY
# Job number  265 added - Data scientist
# Data Scientist
# Milu Health
# Remote
# Job number  266 added - Data Scientist
# Data Scientist - GameOps (Esports)
# PrizePicks
# Remote in Atlanta, GA 30309
# Job number  267 added - Data Scientist - GameOps (Esports)
# Sr. Advertising Data Scientist
# Philo
# San Francisco, CA
# Job number  268 added - Sr. Advertising Data Scientist
# Data Scientist
# WWCM
# Reston, VA 20190
# Job number  269 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  270 added - Senior Open-Source Data Scientist Consultant
# Data Scientist or Engineer
# The Recycling Partnership Inc
# Falls Church, VA 22046
# Job number  271 added - Data Scientist or Engineer
# Data Scientist
# Koch Global Services
# Wichita, KS 67201
# Job number  272 added - Data Scientist
# Data Scientist
# Fusion92
# Remote
# Job number  273 added - Data Scientist
# Data Scientist
# Esource Resources
# Indianapolis, IN
# Job number  274 added - Data Scientist
# Sr Data Scientist
# Pangiam
# McLean, VA
# Job number  275 added - Sr Data Scientist
# Geospatial Data Scientist
# INFOMATICS, INC.
# Mountain View, CA 94035
# Job number  276 added - Geospatial Data Scientist
# Data Scientist III (Applied Research)
# CODAMETRIX
# Boston, MA 02116 (South End area)
# Job number  277 added - Data Scientist III (Applied Research)
# Junior Data Scientist
# Prescient Edge Federal
# Washington, DC 20032 (Anacostia area)
# Job number  278 added - Junior Data Scientist
# Data Engineer / Data Scientist
# Cyberhill Partners LLC
# McLean, VA 22103
# Job number  279 added - Data Engineer / Data Scientist
# Sr. Data Scientist
# omega solutions inc
# Santa Ana, CA
# Job number  280 added - Sr. Data Scientist
# Data Scientist
# Home Depot / THD
# Atlanta, GA 30339
# Job number  281 added - Data Scientist
# Data Scientist
# The College Board
# Remote
# Job number  282 added - Data Scientist
# Data Scientist
# Wizeline
# Remote
# Job number  283 added - Data Scientist
# Data Scientist
# SYSRS IT SERVICES LLC
# Columbia, MD 21044
# Job number  284 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  285 added - Senior Open-Source Data Scientist Consultant
# AI DATA SCIENTIST
# Bureau Veritas
# Hybrid remote in Indianapolis, IN
# Job number  286 added - AI DATA SCIENTIST
# Sr Data Scientist
# Public Storage
# Glendale, CA
# Job number  287 added - Sr Data Scientist
# Process Automation and Data Acquisition Engineer/Scientist
# Boston Government Services Llc
# Washington, DC 20024 (Southwest Federal Center area)
# Job number  288 added - Process Automation and Data Acquisition Engineer/Scientist
# Data Scientist
# INFICON
# East Syracuse, NY 13057
# Job number  289 added - Data Scientist
# Data Scientist
# eHealth
# Remote
# Job number  290 added - Data Scientist
# Data Scientist
# Helix tech IT Solutions
# Remote
# Job number  291 added - Data Scientist
# Data Scientist (Python, LLM, NLP, GenAI)
# Citeline
# Remote
# Job number  292 added - Data Scientist (Python, LLM, NLP, GenAI)
# Data Scientist
# TransVoyant
# Remote
# Job number  293 added - Data Scientist
# Data Scientist
# ST MICHAEL'S INC
# Fayetteville, NC
# Job number  294 added - Data Scientist
# Data Scientist
# Peoplevisor LLC
# Irving, TX 75039
# Job number  295 added - Data Scientist
# Data Scientist
# Stanley David and Associates
# Atlanta, GA 30302 (Vine City area)
# Job number  296 added - Data Scientist
# DATA SCIENTIST
# University of Washington
# Seattle, WA 98195 (University District area)
# Job number  297 added - DATA SCIENTIST
# Data Scientist
# ElectroTempo
# Arlington, VA
# Job number  298 added - Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  299 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# General Dynamics Information Technology
# Hybrid remote in Arlington, VA 22202
# Job number  300 added - Data Scientist
# Data Scientist
# Data Xpander
# Irving, TX
# Job number  301 added - Data Scientist
# Machine Learning Operations Engineer / Data Scientist
# National Security Agency
# Fort Meade, MD
# Job number  302 added - Machine Learning Operations Engineer / Data Scientist
# Sr. Data Scientist-mathematical optimization
# AppsIntegration Inc
# Pleasanton, CA 94566
# Job number  303 added - Sr. Data Scientist-mathematical optimization
# Data Scientist-Healthcare Analytics
# Staffing Solutions Organization LLC (SSO)
# Remote in Albany, NY 12210
# Job number  304 added - Data Scientist-Healthcare Analytics
# Data Scientist Jr. level
# MicroTech
# Remote
# Job number  305 added - Data Scientist Jr. level
# Associate Scientist, Data Review
# Eurofins USA BioPharma Services
# Columbia, MO
# Job number  306 added - Associate Scientist, Data Review
# Data Scientist
# US News & World Report ,L.P.
# Washington, DC 20007 (Georgetown area)
# Job number  307 added - Data Scientist
# Data Scientist
# Elite Insurance Partners
# Tampa, FL
# Job number  308 added - Data Scientist
# Senior Data Scientist
# Realtor.com Careers
# Austin, TX
# Job number  309 added - Senior Data Scientist
# Senior Data Scientist
# eTeam Inc.
# Mountain View, CA
# Job number  310 added - Senior Data Scientist
# Principal Data Scientist
# Denim Health
# Hybrid remote in Austin, TX 78758
# Job number  311 added - Principal Data Scientist
# Data Scientist
# Cenergistic LLC
# Dallas, TX 75225 (North Dallas area)
# Job number  312 added - Data Scientist
# Data Scientist / Engineer
# Shift Technology
# Hybrid remote in Boston, MA
# Job number  313 added - Data Scientist / Engineer
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  314 added - Senior Open-Source Data Scientist Consultant
# Data Analyst
# QinetiQ US
# Washington, DC
# Job number  315 added - Data Analyst
# Data Scientist
# Streamline Defense
# Tampa, FL
# Job number  316 added - Data Scientist
# Data Scientist
# New Jersey Institute of Technology
# Newark, NJ 07102 (Central Business District area)
# Job number  317 added - Data Scientist
# Data Scientist
# Laiba Technologies
# Urbandale, IA 50322
# Job number  318 added - Data Scientist
# Data Scientist I, Risk Analytics
# Oscar Health
# Hybrid remote in New York, NY
# Job number  319 added - Data Scientist I, Risk Analytics
# Data Scientist
# CAI
# Indianapolis, IN
# Job number  320 added - Data Scientist
# Data Scientist
# CVS Health
# Remote in Austin, TX
# Job number  321 added - Data Scientist
# DATA SCIENTIST 2
# Daikin Comfort Technologies
# Waller, TX 77484
# Job number  322 added - DATA SCIENTIST 2
# Data Scientist
# Nicholas and Company
# Salt Lake City, UT 84116 (Jordan Meadows area)
# Job number  323 added - Data Scientist
# Data Scientist
# Dollar Tree
# Chesapeake, VA 23320 (Greenbrier East area)
# Job number  324 added - Data Scientist
# Data Scientist
# Arch Systems, LLC
# Remote
# Job number  325 added - Data Scientist
# Senior Data Scientist (Hybrid)
# OHSU Foundation
# Hybrid remote in Portland, OR 97205
# Job number  326 added - Senior Data Scientist (Hybrid)
# Data Scientist
# AtkinsRéalis
# Austin, TX
# Job number  327 added - Data Scientist
# Sr. Data Scientist (Strategic Insights)
# PlayStation Global
# San Mateo, CA
# Job number  328 added - Sr. Data Scientist (Strategic Insights)
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  329 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Colsh Consultants
# Richfield, MN
# Job number  330 added - Data Scientist
# Data Scientist
# Simplex Info Systems Inc
# New York, NY
# Job number  331 added - Data Scientist
# Data Scientist
# ICF
# Arlington, VA 22209 (Radnor-Ft Myer Heights area)
# Job number  332 added - Data Scientist
# Data Scientist
# Bond Financial Technologies
# Remote
# Job number  333 added - Data Scientist
# R&D Data Scientist
# Biogen
# Cambridge, MA
# Job number  334 added - R&D Data Scientist
# Data Scientist
# Gustaine
# Orange, CA
# Job number  335 added - Data Scientist
# Data Scientist I, Revenue
# Match Group
# Hybrid remote in West Hollywood, CA
# Job number  336 added - Data Scientist I, Revenue
# Data Scientist
# Applied Network Solutions Inc
# Annapolis Junction, MD
# Job number  337 added - Data Scientist
# Data Scientist
# Excella
# Remote in Arlington, VA 22201
# Job number  338 added - Data Scientist
# Data Scientist / Data Modeling
# Blue Water Thinking
# Washington, DC
# Job number  339 added - Data Scientist / Data Modeling
# Data Scientist II
# Leprino Foods
# Denver, CO 80211 (Highland area)
# Job number  340 added - Data Scientist II
# Responsible AI Analyst
# Indeed
# Remote
# Job number  341 added - Responsible AI Analyst
# DST Data Scientist (Collection and Exploitation)
# US Central Intelligence Agency
# Washington, DC
# Job number  342 added - DST Data Scientist (Collection and Exploitation)
# Data Scientist - Bellevue
# RESULTICKS
# Bellevue, WA 98004 (Downtown area)
# Job number  343 added - Data Scientist - Bellevue
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  344 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Tagup
# Hybrid remote in Salt Lake City, UT
# Job number  345 added - Data Scientist
# machine learning (AI / Infrastructure )
# TELLUS SOLUTIONS
# Sunnyvale, CA 94086 (West Murphy area)
# Job number  346 added - machine learning (AI / Infrastructure )
# Principal Data Scientist
# Techstar Group
# Bellevue, WA 98004 (Downtown area)
# Job number  347 added - Principal Data Scientist
# Data Scientist
# HTN Wireless
# Laguna Hills, CA 92653
# Job number  348 added - Data Scientist
# Junior Data Scientist- Trading & Origination
# Statkraft
# Stamford, CT
# Job number  349 added - Junior Data Scientist- Trading & Origination
# Data Analysts
# Sanford Federal, Inc.
# Washington, DC 20001 (Sursum Corda Cooperative area)
# Job number  350 added - Data Analysts
# Data Scientist
# PUTNAM RECRUITING GROUP
# Remote
# Job number  351 added - Data Scientist
# Senior Data Scientist
# UST
# Aliso Viejo, CA
# Job number  352 added - Senior Data Scientist
# Data Scientist and AI Engineer
# SKT Lab
# Santa Clara, CA
# Job number  353 added - Data Scientist and AI Engineer
# Staff Data Scientist
# Chime
# Remote in San Francisco, CA 94108
# Job number  354 added - Staff Data Scientist
# Data Scientist
# Booz Allen Hamilton
# Hybrid remote in Shaw AFB, SC
# Job number  355 added - Data Scientist
# AI Engineer
# Lasso
# San Francisco, CA
# Job number  356 added - AI Engineer
# Data Scientist
# Fractal Analytics
# California
# Job number  357 added - Data Scientist
# Senior Data Scientist - Analytics
# AppLovin
# Palo Alto, CA 94301 (University South area)
# Job number  358 added - Senior Data Scientist - Analytics
# Software Engineer - Machine Learning - IV
# eTeam Inc.
# Remote in San Jose, CA 95131
# Job number  359 added - Software Engineer - Machine Learning - IV
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number  360 added - Senior Open-Source Data Scientist Consultant
# Data Scientist
# Cognowiz solutions LLC
# Herndon, VA 20170
# Job number  361 added - Data Scientist
# Data Scientist
# Home Depot / THD
# Atlanta, GA 30339
# Job number  362 added - Data Scientist
# Data Scientist
# Concurrent Technologies Corporation
# Springfield, VA
# Job number  363 added - Data Scientist
# Generative AI Associate
# Innodata Inc
# Remote
# Job number  364 added - Generative AI Associate
# DATA SCIENTIST 2
# Daikin Comfort Technologies
# Waller, TX 77484
# Job number  365 added - DATA SCIENTIST 2
# Data Scientist
# Valiant Integrated Services
# Herndon, VA 20170
# Job number  366 added - Data Scientist
# Data Scientist
# CVS Health
# Remote in Austin, TX
# Job number  367 added - Data Scientist
# Data Scientist
# Hatch IT
# Hybrid remote in Falls Church, VA
# Job number  368 added - Data Scientist
# Data Scientist
# Spalding Consulting, Inc.
# Remote in Patuxent River, MD
# Job number  369 added - Data Scientist
# Data Scientist
# M. A. Mortenson Company
# Minnesota
# Job number  370 added - Data Scientist
# Data Scientist - Fraud
# Radial, Inc.
# Remote
# Job number  371 added - Data Scientist - Fraud
# Data Scientist
# Global Information Technology
# Texas
# Job number  372 added - Data Scientist
# Data Scientist Lead
# JPMorgan Chase & Co
# Jersey City, NJ 07310 (The Waterfront area)
# Job number  373 added - Data Scientist Lead
# Data Scientist
# Mutual of America Financial Group
# Boca Raton, FL 33487
# Job number  374 added - Data Scientist
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number  375 added - Senior Software Engineer w/AI Focus
# Data Scientist
# Mutual of America Financial Group
# Boca Raton, FL 33487
# Job number  376 added - Data Scientist
# Data Scientist, Marketing
# Asana
# San Francisco, CA
# Job number  377 added - Data Scientist, Marketing
# Data Scientist
# Publicis Media
# New York, NY 10014 (SoHo area)
# Job number  378 added - Data Scientist
# Data Scientist
# Laiba Technologies
# Urbandale, IA 50322
# Job number  379 added - Data Scientist
# Senior Data Scientist- Optimization
# Corteva
# Indianapolis, IN 46268
# Job number  380 added - Senior Data Scientist- Optimization
# Data Scientist
# Globalstar Inc.
# Covington, LA 70433
# Job number  381 added - Data Scientist
# Senior Data Scientist
# Parts Town
# Hybrid remote in Addison, IL 60101
# Job number  382 added - Senior Data Scientist
# Staff Data Scientist
# Devoted Health
# Remote
# Job number  383 added - Staff Data Scientist
# Data Scientist
# SeamlessWorld Consulting
# East Brunswick, NJ
# Job number  384 added - Data Scientist
# Data Scientist (entry-level)
# JRC Integrated Systems, LLC
# Crane, IN 47522
# Job number  385 added - Data Scientist (entry-level)
# Data Scientist
# Arch Systems, LLC
# Remote
# Job number  386 added - Data Scientist
# Drug Discovery Data Scientist
# Schrödinger
# Portland, OR
# Job number  387 added - Drug Discovery Data Scientist
# Data Scientist
# Lawrence Berkeley National Laboratory
# San Francisco Bay Area, CA
# Job number  388 added - Data Scientist
# Senior Data Scientist
# ClinDCast LLC
# Remote
# Job number  389 added - Senior Data Scientist
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number  390 added - Senior Software Engineer w/AI Focus
# Data Scientist Analyst
# Advanced Sciences and Technologies (AS&T)
# Warrenton, VA
# Job number  391 added - Data Scientist Analyst
# Senior Data Scientist
# Pison Technology
# Boston, MA 02111 (Leather District area)
# Job number  392 added - Senior Data Scientist
# Machine Learning Developer
# D. E. Shaw & Co., L.P.
# New York, NY
# Job number  393 added - Machine Learning Developer
# Data Scientist
# SPECIAL AEROSPACE SECURITY
# Chantilly, VA 20151
# Job number  394 added - Data Scientist
# Data Scientist II, Charging & Energy
# Rivian
# Palo Alto, CA 94304
# Job number  395 added - Data Scientist II, Charging & Energy
# Data Scientist
# Integra Connect solutions
# Remote
# Job number  396 added - Data Scientist
# Climate Data Scientist
# ClimateAI
# Remote
# Job number  397 added - Climate Data Scientist
# AI/ML Engineer-Data Scientist
# Noralogic Inc
# Woodland Hills, CA 91303
# Job number  398 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# UST
# Aliso Viejo, CA
# Job number  399 added - Senior Data Scientist
# Applied Data Scientist
# Gentex Corporation
# Zeeland, MI
# Job number  400 added - Applied Data Scientist
# Senior Data Scientist
# Adobe
# San Jose, CA 95110 (Downtown area)
# Job number  401 added - Senior Data Scientist
# Data Scientist
# Lightsource BP
# Denver, CO
# Job number  402 added - Data Scientist
# Data Scientist
# IT Consulting Services
# Fairless Hills, PA
# Job number  403 added - Data Scientist
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number  404 added - Senior Software Engineer w/AI Focus
# Jr. Data Scientist, Minerva Analytics
# Amazon.com Services LLC
# San Diego, CA
# Job number  405 added - Jr. Data Scientist, Minerva Analytics
# Sr. Data Scientist
# Bright MLS, Inc
# North Bethesda, MD 20852
# Job number  406 added - Sr. Data Scientist
# AI/ML Engineer
# Chabez Tech
# Remote in Washington, DC
# Job number  407 added - AI/ML Engineer
# Data Scientist
# Stanley David and Associates
# Atlanta, GA 30302 (Vine City area)
# Job number  408 added - Data Scientist
# Lead Data Scientist
# MORSE Corp
# Cambridge, MA
# Job number  409 added - Lead Data Scientist
# Senior Data Scientist - Optimization
# AutoGrid Systems
# Redwood City, CA 94065
# Job number  410 added - Senior Data Scientist - Optimization
# Data Scientist
# Key Cyber Solutions
# Richmond, VA
# Job number  411 added - Data Scientist
# Data Scientist
# ACI Federal Inc
# Bethesda, MD 20892
# Job number  412 added - Data Scientist
# Data Scientist
# McIntire Solutions
# Springfield, VA 22150
# Job number  413 added - Data Scientist
# Real World Data Scientist, RWDA
# Tempus
# San Francisco, CA
# Job number  414 added - Real World Data Scientist, RWDA
# Data Scientist
# Nyla Technology Solutions
# Washington, DC
# Job number  415 added - Data Scientist
# Data Scientist
# NORC at the University of Chicago
# Chicago, IL
# Job number  416 added - Data Scientist
# Data Scientist
# Markesman Group
# Fort Eisenhower, GA 30905
# Job number  417 added - Data Scientist
# Data Scientist
# Atlantis IT group
# Troy, MI
# Job number  418 added - Data Scientist
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number  419 added - Senior Software Engineer w/AI Focus
# Data Scientist 4739
# MetroStar
# Washington, DC
# Job number  420 added - Data Scientist 4739
# Data Scientist
# Dataline
# Princeton, NJ 08540
# Job number  421 added - Data Scientist
# Data Scientist
# International Services Management
# Pittsburgh, PA
# Job number  422 added - Data Scientist
# Data Scientist (L5) - Identity Algorithms
# Netflix
# Los Gatos, CA
# Job number  423 added - Data Scientist (L5) - Identity Algorithms
# Data Scientist II
# Clear Resolution Consulting, LLC
# Aurora, CO
# Job number  424 added - Data Scientist II
# Data Scientist 3
# Skaggs Consulting, Inc.
# Washington, DC
# Job number  425 added - Data Scientist 3
# Data Scientist II
# Warrant Technologies
# Bloomington, IN 47404
# Job number  426 added - Data Scientist II
# Data Scientist, RegLab
# Stanford University
# Stanford, CA
# Job number  427 added - Data Scientist, RegLab
# Data Scientist
# Sasol
# Lake Charles, LA
# Job number  428 added - Data Scientist
# Data Scientist
# Tek Ninjas
# Texas
# Job number  429 added - Data Scientist
# Data Analyst – Data Entry
# Juristat
# Remote
# Job number  430 added - Data Analyst – Data Entry
# Data Scientist with people soft
# Spanco Solutions
# Indianapolis, IN
# Job number  431 added - Data Scientist with people soft
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number  432 added - Senior Software Engineer w/AI Focus
# Data Scientist
# Hyperspace Ventures
# Durham, NC
# Job number  433 added - Data Scientist
# Data Scientist
# General Dynamics Information Technology
# Hybrid remote in Arlington, VA 22202
# Job number  434 added - Data Scientist
# Data Scientist
# Software Bloc
# Plano, TX
# Job number  435 added - Data Scientist
# Data Scientist
# Software Bloc
# Plano, TX
# Job number  436 added - Data Scientist
# Data Scientist
# KesarWeb
# Remote in Baltimore, MD
# Job number  437 added - Data Scientist
# Data Scientist
# Technology Solutions Partners
# Olathe, KS 66061 (Downtown area)
# Job number  438 added - Data Scientist
# Data Scientist
# DLA Piper
# New York, NY
# Job number  439 added - Data Scientist
# Lead Machine Learning Scientist
# Wayfair
# Mountain View, CA
# Job number  440 added - Lead Machine Learning Scientist
# Principal Data Scientist
# Plume
# Palo Alto, CA
# Job number  441 added - Principal Data Scientist
# Data Engineer
# Walmart Advanced Systems and Robotics
# Andover, MA
# Job number  442 added - Data Engineer
# Senior Data Scientist (Hybrid)
# OHSU Foundation
# Hybrid remote in Portland, OR 97205
# Job number  443 added - Senior Data Scientist (Hybrid)
# Mathematical Scientist
# Pit.AI Technologies Inc.
# San Jose, CA 95131 (North Valley area)
# Job number  444 added - Mathematical Scientist
# Data Scientist
# Aperio Clinical Outcomes
# Durham, NC 27701
# Job number  445 added - Data Scientist
# Data Scientist
# Bond Financial Technologies
# Remote
# Job number  446 added - Data Scientist
# Data Scientist - GameOps (Esports)
# PrizePicks
# Remote in Atlanta, GA 30309
# Job number  447 added - Data Scientist - GameOps (Esports)
# Geospatial Data Scientist
# ADAPT Technology LLC.
# Hybrid remote in Mountain View, CA 94043
# Job number  448 added - Geospatial Data Scientist
# Data Scientist (C)
# Mainsailgroup.com
# Reston, VA
# Job number  449 added - Data Scientist (C)
# Senior Software Engineer w/AI Focus
# InfoEd Global
# Remote
# Job number  450 added - Senior Software Engineer w/AI Focus
# Data Scientist
# ARKHO
# Remote
# Job number  451 added - Data Scientist
# data scientist, Global Supply Chain
# Starbucks
# Seattle, WA 98134 (Industrial District area)
# Job number  452 added - data scientist, Global Supply Chain
# Data Scientist
# eureka strategic consulting
# Columbia, MD 21045
# Job number  453 added - Data Scientist
# Data Scientist
# Pantheon Data
# Springfield, VA 22150
# Job number  454 added - Data Scientist
# Data Scientist
# US Department of Energy - Agency Wide
# Wallops Island, VA
# Job number  455 added - Data Scientist
# Data Scientist
# Fullpower Technologies, Inc.
# Santa Cruz, CA 95060
# Job number  456 added - Data Scientist
# Sr. / Staff Data Scientist
# MasterClass
# Remote in San Francisco, CA
# Job number  457 added - Sr. / Staff Data Scientist
# Data Scientist
# DataStudio
# Remote
# Job number  458 added - Data Scientist
# Data Scientist
# Human Rights First
# Remote
# Job number  459 added - Data Scientist
# Senior Data Scientist
# Alteryx, Inc.
# Michigan
# Job number  460 added - Senior Data Scientist
# Principal Data Scientist
# OneTrust
# Remote in Atlanta, GA
# ...
# Job number 1215 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1216 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1217 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1218 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1219 added - Data Scientist
# Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# U.S. Bank National Association
# Remote
# Job number 1220 added - Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# Sr. Data Analyst (IT10000009B_1b)
# Synectics for Management Decisions Inc
# Hybrid remote in Alexandria, VA 22314
# Job number 1221 added - Sr. Data Analyst (IT10000009B_1b)
# Senior Data Scientist
# Pashtek
# Remote in Texas City, TX
# Job number 1222 added - Senior Data Scientist
# Data Scientist (remote)
# Yardzen
# Remote in Sausalito, CA
# Job number 1223 added - Data Scientist (remote)
# Senior Data Scientist
# Tokio Marine HCC
# Hybrid remote in Houston, TX 77040
# Job number 1224 added - Senior Data Scientist
# Data Scientist 2
# Aioi Nissay Dowa Insurance Services USA
# Hybrid remote in Torrance, CA 90501
# Job number 1225 added - Data Scientist 2
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number 1226 added - Senior Open-Source Data Scientist Consultant
# AI/ML Engineer-Data Scientist
# Datawize Technologies Inc
# Mason, OH 45040
# Job number 1227 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# Fiserv, Inc.
# Berkeley Heights, NJ 07922
# Job number 1228 added - Senior Data Scientist
# watsonX AI Client Engineer - Generative AI
# IBM
# Research Triangle Park, NC 27709
# Job number 1229 added - watsonX AI Client Engineer - Generative AI
# Sr Tableau Data Analyst
# Dutech
# Austin, TX 78701 (Downtown area)
# Job number 1230 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1231 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1232 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1233 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1234 added - Data Scientist
# Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# U.S. Bank National Association
# Remote
# Job number 1235 added - Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# Sr. Data Analyst (IT10000009B_1b)
# Synectics for Management Decisions Inc
# Hybrid remote in Alexandria, VA 22314
# Job number 1236 added - Sr. Data Analyst (IT10000009B_1b)
# Senior Data Scientist
# Pashtek
# Remote in Texas City, TX
# Job number 1237 added - Senior Data Scientist
# Data Scientist (remote)
# Yardzen
# Remote in Sausalito, CA
# Job number 1238 added - Data Scientist (remote)
# Senior Data Scientist
# Tokio Marine HCC
# Hybrid remote in Houston, TX 77040
# Job number 1239 added - Senior Data Scientist
# Data Scientist 2
# Aioi Nissay Dowa Insurance Services USA
# Hybrid remote in Torrance, CA 90501
# Job number 1240 added - Data Scientist 2
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number 1241 added - Senior Open-Source Data Scientist Consultant
# AI/ML Engineer-Data Scientist
# Datawize Technologies Inc
# Mason, OH 45040
# Job number 1242 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# Fiserv, Inc.
# Berkeley Heights, NJ 07922
# Job number 1243 added - Senior Data Scientist
# watsonX AI Client Engineer - Generative AI
# IBM
# Research Triangle Park, NC 27709
# Job number 1244 added - watsonX AI Client Engineer - Generative AI
# Sr Tableau Data Analyst
# Dutech
# Austin, TX 78701 (Downtown area)
# Job number 1245 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1246 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1247 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1248 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1249 added - Data Scientist
# Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# U.S. Bank National Association
# Remote
# Job number 1250 added - Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# Sr. Data Analyst (IT10000009B_1b)
# Synectics for Management Decisions Inc
# Hybrid remote in Alexandria, VA 22314
# Job number 1251 added - Sr. Data Analyst (IT10000009B_1b)
# Senior Data Scientist
# Pashtek
# Remote in Texas City, TX
# Job number 1252 added - Senior Data Scientist
# Data Scientist (remote)
# Yardzen
# Remote in Sausalito, CA
# Job number 1253 added - Data Scientist (remote)
# Senior Data Scientist
# Tokio Marine HCC
# Hybrid remote in Houston, TX 77040
# Job number 1254 added - Senior Data Scientist
# Data Scientist 2
# Aioi Nissay Dowa Insurance Services USA
# Hybrid remote in Torrance, CA 90501
# Job number 1255 added - Data Scientist 2
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number 1256 added - Senior Open-Source Data Scientist Consultant
# AI/ML Engineer-Data Scientist
# Datawize Technologies Inc
# Mason, OH 45040
# Job number 1257 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# Fiserv, Inc.
# Berkeley Heights, NJ 07922
# Job number 1258 added - Senior Data Scientist
# watsonX AI Client Engineer - Generative AI
# IBM
# Research Triangle Park, NC 27709
# Job number 1259 added - watsonX AI Client Engineer - Generative AI
# Sr Tableau Data Analyst
# Dutech
# Austin, TX 78701 (Downtown area)
# Job number 1260 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1261 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1262 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1263 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1264 added - Data Scientist
# Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# U.S. Bank National Association
# Remote
# Job number 1265 added - Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# Sr. Data Analyst (IT10000009B_1b)
# Synectics for Management Decisions Inc
# Hybrid remote in Alexandria, VA 22314
# Job number 1266 added - Sr. Data Analyst (IT10000009B_1b)
# Senior Data Scientist
# Pashtek
# Remote in Texas City, TX
# Job number 1267 added - Senior Data Scientist
# Data Scientist (remote)
# Yardzen
# Remote in Sausalito, CA
# Job number 1268 added - Data Scientist (remote)
# Senior Data Scientist
# Tokio Marine HCC
# Hybrid remote in Houston, TX 77040
# Job number 1269 added - Senior Data Scientist
# Data Scientist 2
# Aioi Nissay Dowa Insurance Services USA
# Hybrid remote in Torrance, CA 90501
# Job number 1270 added - Data Scientist 2
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number 1271 added - Senior Open-Source Data Scientist Consultant
# AI/ML Engineer-Data Scientist
# Datawize Technologies Inc
# Mason, OH 45040
# Job number 1272 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# Fiserv, Inc.
# Berkeley Heights, NJ 07922
# Job number 1273 added - Senior Data Scientist
# watsonX AI Client Engineer - Generative AI
# IBM
# Research Triangle Park, NC 27709
# Job number 1274 added - watsonX AI Client Engineer - Generative AI
# Sr Tableau Data Analyst
# Dutech
# Austin, TX 78701 (Downtown area)
# Job number 1275 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1276 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1277 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1278 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1279 added - Data Scientist
# Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# U.S. Bank National Association
# Remote
# Job number 1280 added - Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# Sr. Data Analyst (IT10000009B_1b)
# Synectics for Management Decisions Inc
# Hybrid remote in Alexandria, VA 22314
# Job number 1281 added - Sr. Data Analyst (IT10000009B_1b)
# Senior Data Scientist
# Pashtek
# Remote in Texas City, TX
# Job number 1282 added - Senior Data Scientist
# Data Scientist (remote)
# Yardzen
# Remote in Sausalito, CA
# Job number 1283 added - Data Scientist (remote)
# Senior Data Scientist
# Tokio Marine HCC
# Hybrid remote in Houston, TX 77040
# Job number 1284 added - Senior Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number 1285 added - Senior Open-Source Data Scientist Consultant
# Data Scientist 2
# Aioi Nissay Dowa Insurance Services USA
# Hybrid remote in Torrance, CA 90501
# Job number 1286 added - Data Scientist 2
# AI/ML Engineer-Data Scientist
# Datawize Technologies Inc
# Mason, OH 45040
# Job number 1287 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# Fiserv, Inc.
# Berkeley Heights, NJ 07922
# Job number 1288 added - Senior Data Scientist
# watsonX AI Client Engineer - Generative AI
# IBM
# Research Triangle Park, NC 27709
# Job number 1289 added - watsonX AI Client Engineer - Generative AI
# Sr Tableau Data Analyst
# Dutech
# Austin, TX 78701 (Downtown area)
# Job number 1290 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1291 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1292 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1293 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1294 added - Data Scientist
# Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# U.S. Bank National Association
# Remote
# Job number 1295 added - Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# Sr. Data Analyst (IT10000009B_1b)
# Synectics for Management Decisions Inc
# Hybrid remote in Alexandria, VA 22314
# Job number 1296 added - Sr. Data Analyst (IT10000009B_1b)
# Senior Data Scientist
# Pashtek
# Remote in Texas City, TX
# Job number 1297 added - Senior Data Scientist
# Data Scientist (remote)
# Yardzen
# Remote in Sausalito, CA
# Job number 1298 added - Data Scientist (remote)
# Senior Data Scientist
# Tokio Marine HCC
# Hybrid remote in Houston, TX 77040
# Job number 1299 added - Senior Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number 1300 added - Senior Open-Source Data Scientist Consultant
# Data Scientist 2
# Aioi Nissay Dowa Insurance Services USA
# Hybrid remote in Torrance, CA 90501
# Job number 1301 added - Data Scientist 2
# AI/ML Engineer-Data Scientist
# Datawize Technologies Inc
# Mason, OH 45040
# Job number 1302 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# Fiserv, Inc.
# Berkeley Heights, NJ 07922
# Job number 1303 added - Senior Data Scientist
# watsonX AI Client Engineer - Generative AI
# IBM
# Research Triangle Park, NC 27709
# Job number 1304 added - watsonX AI Client Engineer - Generative AI
# Sr Tableau Data Analyst
# Dutech
# Austin, TX 78701 (Downtown area)
# Job number 1305 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1306 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1307 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1308 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1309 added - Data Scientist
# Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# U.S. Bank National Association
# Remote
# Job number 1310 added - Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# Sr. Data Analyst (IT10000009B_1b)
# Synectics for Management Decisions Inc
# Hybrid remote in Alexandria, VA 22314
# Job number 1311 added - Sr. Data Analyst (IT10000009B_1b)
# Senior Data Scientist
# Pashtek
# Remote in Texas City, TX
# Job number 1312 added - Senior Data Scientist
# Data Scientist (remote)
# Yardzen
# Remote in Sausalito, CA
# Job number 1313 added - Data Scientist (remote)
# Senior Data Scientist
# Tokio Marine HCC
# Hybrid remote in Houston, TX 77040
# Job number 1314 added - Senior Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number 1315 added - Senior Open-Source Data Scientist Consultant
# Data Scientist 2
# Aioi Nissay Dowa Insurance Services USA
# Hybrid remote in Torrance, CA 90501
# Job number 1316 added - Data Scientist 2
# AI/ML Engineer-Data Scientist
# Datawize Technologies Inc
# Mason, OH 45040
# Job number 1317 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# Fiserv, Inc.
# Berkeley Heights, NJ 07922
# Job number 1318 added - Senior Data Scientist
# watsonX AI Client Engineer - Generative AI
# IBM
# Research Triangle Park, NC 27709
# Job number 1319 added - watsonX AI Client Engineer - Generative AI
# Sr Tableau Data Analyst
# Dutech
# Austin, TX 78701 (Downtown area)
# Job number 1320 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1321 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1322 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1323 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1324 added - Data Scientist
# Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# U.S. Bank National Association
# Remote
# Job number 1325 added - Senior Data Scientist Operations Consumer/Mortgage Banking - Remote
# Sr. Data Analyst (IT10000009B_1b)
# Synectics for Management Decisions Inc
# Hybrid remote in Alexandria, VA 22314
# Job number 1326 added - Sr. Data Analyst (IT10000009B_1b)
# Senior Data Scientist
# Pashtek
# Remote in Texas City, TX
# Job number 1327 added - Senior Data Scientist
# Data Scientist (remote)
# Yardzen
# Remote in Sausalito, CA
# Job number 1328 added - Data Scientist (remote)
# Senior Data Scientist
# Tokio Marine HCC
# Hybrid remote in Houston, TX 77040
# Job number 1329 added - Senior Data Scientist
# Senior Open-Source Data Scientist Consultant
# Guidehouse
# Reston, VA 22096
# Job number 1330 added - Senior Open-Source Data Scientist Consultant
# Data Scientist 2
# Aioi Nissay Dowa Insurance Services USA
# Hybrid remote in Torrance, CA 90501
# Job number 1331 added - Data Scientist 2
# AI/ML Engineer-Data Scientist
# Datawize Technologies Inc
# Mason, OH 45040
# Job number 1332 added - AI/ML Engineer-Data Scientist
# Senior Data Scientist
# Fiserv, Inc.
# Berkeley Heights, NJ 07922
# Job number 1333 added - Senior Data Scientist
# watsonX AI Client Engineer - Generative AI
# IBM
# Research Triangle Park, NC 27709
# Job number 1334 added - watsonX AI Client Engineer - Generative AI
# Sr Tableau Data Analyst
# Dutech
# Austin, TX 78701 (Downtown area)
# Job number 1335 added - Sr Tableau Data Analyst
# Customer Engineer, AI/ML
# Google
# San Francisco, CA
# Job number 1336 added - Customer Engineer, AI/ML
# Data Scientist II - Tsui Lab
# Children’s Hospital of Philadelphia
# Philadelphia, PA 19104 (University City area)
# Job number 1337 added - Data Scientist II - Tsui Lab
# Sr. Data Scientist, Analytics - Ads
# Quizlet
# New York, NY
# Job number 1338 added - Sr. Data Scientist, Analytics - Ads
# Data Scientist
# Worldwide Flight Services
# Irving, TX
# Job number 1339 added - Data Scientist

# %%
dataframe.head()
# Out:
#                                                Title  \
# 0                             Principal Data Science
# 1                                     Data Scientist
# 2  Scientist/Principal Scientist, Drug Product De...
# 3                                     Data Scientist
# 4                                     Data Scientist
#
#                        Company                Location Rating  \
# 0  Discover Financial Services    Riverwoods, IL 60015    NaN
# 1                         SOSi    Redstone Arsenal, AL    NaN
# 2         Bristol Myers Squibb        Summit, NJ 07901    NaN
# 3              Kaizen Analytix                  Remote    NaN
# 4       NYC Health + Hospitals  Remote in New York, NY    NaN
#
#                         Date                      Salary  \
# 0  PostedPosted 30+ days ago  $123,500 - $173,100 a year
# 1  PostedPosted 30+ days ago                         NaN
# 2  PostedPosted 30+ days ago                         NaN
# 3    PostedPosted 2 days ago                         NaN
# 4    PostedPosted 6 days ago                         NaN
#
#                                          Description  \
# 0  Leads the development and implementation of ad...
# 1  You will leverage scientific techniques to tra...
# 2  Trains scientists in data analysis, statistics...
# 3  PhD in Operations Research, Econometrics, or o...
# 4  Apply statistical techniques and machine learn...
#
#                                                Links
# 0  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 1  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 2  https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# 3  https://www.indeed.com/rc/clk?jk=3e8ec49d1c707...
# 4  https://www.indeed.com/rc/clk?jk=39620c4b48632...

# %% [markdown]
# ### Scrape Full Job Descriptions

# %%
Links_list = dataframe['Links'].tolist()
#Links_list

# %%
descriptions=[]
for i in Links_list:
    driver.get(i)
    driver.implicitly_wait(random.randint(3, 8))
    jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
    descriptions.append(jd)
    time.sleep(random.randint(5,10))

dataframe['Descriptions'] = descriptions

# %%
print(dataframe.shape)
# Out:
# (1339, 9)

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)
